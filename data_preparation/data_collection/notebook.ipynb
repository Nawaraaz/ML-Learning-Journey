# %%
# data can be collected from different sources
# to load data in pandas we use read_csv: for csv, for excel we use read_excel similarly we can explore other concepts

import pandas as pd # this will import python libraries

#df = pd.read_csv('data_path')

df = pd.read_csv('dummy_dataset.csv')

print(df.head()) # this will display the top 5 rows of the data
